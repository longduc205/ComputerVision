# %% [markdown]
# # Domain Analysis: Climate Zone & Disaster Variability
#
# Analyzes visual differences between climate zones and disaster events. Generates t-SNE visualizations of feature distributions.
